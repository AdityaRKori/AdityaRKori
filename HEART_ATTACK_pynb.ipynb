# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/heart_attack_prediction_dataset_edit.csv')

# %%
df.shape
# Out:
# (8763, 26)

# %%
df.head()
# Out:
#   Patient ID   Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    BMW7812  67.0       m          208         158/88          72       0.0
# 1    CZE1114  21.0    male          389         165/93          98       1.0
# 2    BNI9906  21.0  Female          324         174/99          72       1.0
# 3    JLN3497  84.0     NaN          383        163/100          73       1.0
# 4    GFO8847  66.0    Male          318          91/88          93       NaN
#
#    Family History  Smoking  Obesity  ...  Sedentary Hours Per Day    Income  \
# 0             0.0        1        0  ...                 6.615001  261404.0
# 1             1.0        1        1  ...                 4.963459  285768.0
# 2             0.0        0        0  ...                 9.463426  235282.0
# 3             1.0        1        0  ...                 7.648981  125640.0
# 4             1.0        1        1  ...                 1.514821  160555.0
#
# ...

# %%
df.columns
# Out:
# Index(['Patient ID', 'Age', 'Sex', 'Cholesterol', 'Blood Pressure',
#        'Heart Rate', 'Diabetes', 'Family History', 'Smoking', 'Obesity',
#        'Alcohol Consumption', 'Exercise Hours Per Week', 'Diet',
#        'Previous Heart Problems', 'Medication Use', 'Stress Level',
#        'Sedentary Hours Per Day', 'Income', 'BMI', 'Triglycerides',
#        'Physical Activity Days Per Week', 'Sleep Hours Per Day', 'Country',
#        'Continent', 'Hemisphere', 'Heart Attack Risk'],
#       dtype='object')

# %%
df=df.drop_duplicates(subset=['Patient ID'])

# %%
df.shape
# Out:
# (8763, 26)

# %%
df.dtypes
# Out:
# Patient ID                          object
# Age                                float64
# Sex                                 object
# Cholesterol                          int64
# Blood Pressure                      object
# Heart Rate                           int64
# Diabetes                           float64
# Family History                     float64
# Smoking                              int64
# Obesity                              int64
# Alcohol Consumption                  int64
# Exercise Hours Per Week            float64
# Diet                                object
# Previous Heart Problems              int64
# Medication Use                       int64
# Stress Level                         int64
# Sedentary Hours Per Day            float64
# Income                             float64
# BMI                                float64
# Triglycerides                        int64
# Physical Activity Days Per Week      int64
# Sleep Hours Per Day                float64
# ...

# %%
df.isnull().sum()
# Out:
# Patient ID                         0
# Age                                2
# Sex                                1
# Cholesterol                        0
# Blood Pressure                     1
# Heart Rate                         0
# Diabetes                           1
# Family History                     1
# Smoking                            0
# Obesity                            0
# Alcohol Consumption                0
# Exercise Hours Per Week            0
# Diet                               0
# Previous Heart Problems            0
# Medication Use                     0
# Stress Level                       0
# Sedentary Hours Per Day            2
# Income                             1
# BMI                                0
# Triglycerides                      0
# Physical Activity Days Per Week    0
# Sleep Hours Per Day                1
# Country                            0
# Continent                          0
# Hemisphere                         0
# ...

# %%
category_cols=df.select_dtypes(include='object').columns
for col in category_cols:
  print(df[col].unique())
# Out:
# ['BMW7812' 'CZE1114' 'BNI9906' ... 'XKA5925' 'EPE6801' 'ZWN9666']
# ['m' 'male' 'Female' nan 'Male' 'f']
# ['158/88' '165/93' '174/99' ... '137/94' '94/76' '119/67']
# ['Average' 'Unhealthy' 'Healthy' 'Unhelthy' 'Healty']
# ['Argentina' 'Canada' 'France' 'Thailand' 'Germany' 'Japan' 'Brazil'
#  'South Africa' 'United States' 'Vietnam' 'China' 'Italy' 'Spain' 'India'
#  'Nigeria' 'New Zealand' 'South Korea' 'Australia' 'Colombia'
#  'United Kingdom']
# ['South America' 'North America' 'Europe' 'Asia' 'Africa' 'Australia']
# ['Southern Hemisphere' 'Northern Hemisphere']

# %%
df.columns
# Out:
# Index(['Patient ID', 'Age', 'Sex', 'Cholesterol', 'Blood Pressure',
#        'Heart Rate', 'Diabetes', 'Family History', 'Smoking', 'Obesity',
#        'Alcohol Consumption', 'Exercise Hours Per Week', 'Diet',
#        'Previous Heart Problems', 'Medication Use', 'Stress Level',
#        'Sedentary Hours Per Day', 'Income', 'BMI', 'Triglycerides',
#        'Physical Activity Days Per Week', 'Sleep Hours Per Day', 'Country',
#        'Continent', 'Hemisphere', 'Heart Attack Risk'],
#       dtype='object')

# %%
import pandas as pd

try:
    df[['Systolic_Blood Pressure', 'Diastolic_Blood Pressure']] = df['Blood Pressure'].str.split('/', expand=True)
    df['Systolic_Blood Pressure'] = pd.to_numeric(df['Systolic_Blood Pressure'], errors='coerce')
    df['Diastolic_Blood Pressure'] = pd.to_numeric(df['Diastolic_Blood Pressure'], errors='coerce')
    # To see the output, run the code.
    print(df.head())
except:
    print("Error: 'Blood Pressure' column not found or data format is incorrect.")
# Out:
#   Patient ID   Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    BMW7812  67.0       m          208         158/88          72       0.0
# 1    CZE1114  21.0    male          389         165/93          98       1.0
# 2    BNI9906  21.0  Female          324         174/99          72       1.0
# 3    JLN3497  84.0     NaN          383        163/100          73       1.0
# 4    GFO8847  66.0    Male          318          91/88          93       NaN
#
#    Family History  Smoking  Obesity  ...        BMI  Triglycerides  \
# 0             0.0        1        0  ...  31.251233            286
# 1             1.0        1        1  ...  27.194973            235
# 2             0.0        0        0  ...  28.176571            587
# 3             1.0        1        0  ...  36.464704            378
# 4             1.0        1        1  ...  21.809144            231
#
#   Physical Activity Days Per Week  Sleep Hours Per Day    Country  \
# ...

# %%
df.columns
# Out:
# Index(['Patient ID', 'Age', 'Sex', 'Cholesterol', 'Blood Pressure',
#        'Heart Rate', 'Diabetes', 'Family History', 'Smoking', 'Obesity',
#        'Alcohol Consumption', 'Exercise Hours Per Week', 'Diet',
#        'Previous Heart Problems', 'Medication Use', 'Stress Level',
#        'Sedentary Hours Per Day', 'Income', 'BMI', 'Triglycerides',
#        'Physical Activity Days Per Week', 'Sleep Hours Per Day', 'Country',
#        'Continent', 'Hemisphere', 'Heart Attack Risk',
#        'Systolic_Blood Pressure', 'Diastolic_Blood Pressure'],
#       dtype='object')

# %%
import numpy as np

for I in ["Age","BMI","Cholesterol","Exercise Hours Per Week","Stress Level","Sedentary Hours Per Day",
          "Income", "BMI", "Triglycerides",  "Physical Activity Days Per Week", "Sleep Hours Per Day",
          "Systolic_Blood Pressure","Diastolic_Blood Pressure"]:

    Q1 = df[I].quantile(0.25)

    Q3 = df[I].quantile(0.75)

    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR

    upper_bound = Q3 + 1.5 * IQR

    df = df[(df[I] >= lower_bound) & (df[I] <= upper_bound)]

print(df.shape)
# Out:
# (8756, 28)

# %%
df['Sex'].fillna(df['Sex'].mode()[0], inplace = True)
df['Sex'] = df['Sex'].replace({'male': 'Male','f': 'Female'})
# Out:
# <ipython-input-15-b02a2de2f2f2>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Sex'].fillna(df['Sex'].mode()[0], inplace = True)

# %%
df['Sex'].fillna(df['Sex'].mode()[0], inplace = True)
df['Sex'] = df['Sex'].replace({'m': 'Male','f': 'Female'})
# Out:
# <ipython-input-16-d948a587fbc2>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Sex'].fillna(df['Sex'].mode()[0], inplace = True)

# %%
df['Diet'].fillna(df['Diet'].mode()[0], inplace = True)
df['Diet'] = df['Diet'].replace({'Unhelthy': 'Unhealthy','Healty': 'Healthy'})
# Out:
# <ipython-input-17-628f5ccb8970>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Diet'].fillna(df['Diet'].mode()[0], inplace = True)

# %%
df['Diet'].unique()
# Out:
# array(['Average', 'Unhealthy', 'Healthy'], dtype=object)

# %%
for i in df.select_dtypes(include='object').columns:
 df[i].fillna(df[i].mode()[0], inplace = True)
# Out:
# <ipython-input-19-ae97157b7ec2>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[i].fillna(df[i].mode()[0], inplace = True)

# %%
for i in df.select_dtypes(include = np.number).columns[:-1]:
 df[i] = df[i].fillna(df[i].mean())

# %%
df=df.dropna(subset=['Heart Attack Risk','Patient ID','Blood Pressure','Country'])

# %%
# prompt: drop the column 'Heart Attack Risk', 'Patient ID' ,'Blood Pressure'

df = df.drop(columns=[ 'Patient ID', 'Blood Pressure'])

# %%
df.isnull().sum()
# Out:
# Age                                0
# Sex                                0
# Cholesterol                        0
# Heart Rate                         0
# Diabetes                           0
# Family History                     0
# Smoking                            0
# Obesity                            0
# Alcohol Consumption                0
# Exercise Hours Per Week            0
# Diet                               0
# Previous Heart Problems            0
# Medication Use                     0
# Stress Level                       0
# Sedentary Hours Per Day            0
# Income                             0
# BMI                                0
# Triglycerides                      0
# Physical Activity Days Per Week    0
# Sleep Hours Per Day                0
# Country                            0
# Continent                          0
# Hemisphere                         0
# Heart Attack Risk                  0
# Systolic_Blood Pressure            0
# ...

# %%
df.head(30)
# Out:
#      Age     Sex  Cholesterol  Heart Rate  Diabetes  Family History  Smoking  \
# 0   67.0    Male          208          72  0.000000        0.000000        1
# 1   21.0    Male          389          98  1.000000        1.000000        1
# 2   21.0  Female          324          72  1.000000        0.000000        0
# 3   84.0    Male          383          73  1.000000        1.000000        1
# 4   66.0    Male          318          93  0.652199        1.000000        1
# 6   90.0    Male          358          84  0.000000        0.000000        1
# 7   84.0    Male          220         107  0.000000        0.000000        1
# 12  77.0    Male          228          68  1.000000        1.000000        1
# 13  60.0    Male          259          85  1.000000        0.492861        1
# 14  88.0    Male          297         102  1.000000        1.000000        1
# 15  73.0    Male          122          97  1.000000        1.000000        1
# ...

# %%
category_cols=df.select_dtypes(include='object').columns
for col in category_cols:
  print(df[col].unique())
# Out:
# ['Male' 'Female']
# ['Average' 'Unhealthy' 'Healthy']
# ['Argentina' 'Canada' 'France' 'Thailand' 'Japan' 'Vietnam' 'China'
#  'Italy' 'Brazil' 'Spain' 'India' 'Nigeria' 'New Zealand' 'United States'
#  'South Korea' 'Germany' 'Australia' 'South Africa' 'Colombia'
#  'United Kingdom']
# ['South America' 'North America' 'Europe' 'Asia' 'Africa' 'Australia']
# ['Southern Hemisphere' 'Northern Hemisphere']

# %%
df.head()
# Out:
#     Age     Sex  Cholesterol  Heart Rate  Diabetes  Family History  Smoking  \
# 0  67.0    Male          208          72  0.000000             0.0        1
# 1  21.0    Male          389          98  1.000000             1.0        1
# 2  21.0  Female          324          72  1.000000             0.0        0
# 3  84.0    Male          383          73  1.000000             1.0        1
# 4  66.0    Male          318          93  0.652199             1.0        1
#
#    Obesity  Alcohol Consumption  Exercise Hours Per Week  ...        BMI  \
# 0        0                    0                 4.168189  ...  31.251233
# 1        1                    1                 1.813242  ...  27.194973
# 2        0                    0                 2.078353  ...  28.176571
# 3        0                    1                 9.828130  ...  36.464704
# 4        1                    0                 5.804299  ...  21.809144
#
# ...

# %%
# prompt: which are categorical columns in this dataset

# Assuming the code you provided has been executed and the DataFrame 'df' is available.

# Identify categorical columns
category_cols = df.select_dtypes(include='object').columns

# Print the unique values for each categorical column
for col in category_cols:
    print(f"Column: {col}, Unique Values: {df[col].unique()}")
# Out:
# Column: Sex, Unique Values: ['Male' 'Female']
# Column: Diet, Unique Values: ['Average' 'Unhealthy' 'Healthy']
# Column: Country, Unique Values: ['Argentina' 'Canada' 'France' 'Thailand' 'Japan' 'Vietnam' 'China'
#  'Italy' 'Brazil' 'Spain' 'India' 'Nigeria' 'New Zealand' 'United States'
#  'South Korea' 'Germany' 'Australia' 'South Africa' 'Colombia'
#  'United Kingdom']
# Column: Continent, Unique Values: ['South America' 'North America' 'Europe' 'Asia' 'Africa' 'Australia']
# Column: Hemisphere, Unique Values: ['Southern Hemisphere' 'Northern Hemisphere']

# %%
# prompt: just give me encoded code for this categorical column

from sklearn.preprocessing import LabelEncoder

# Assuming 'df' and 'category_cols' are already defined as in your previous code

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Encode each categorical column
for col in category_cols:
    df[col] = label_encoder.fit_transform(df[col])

# Print the encoded DataFrame
print(df.head())
# Out:
#     Age  Sex  Cholesterol  Heart Rate  Diabetes  Family History  Smoking  \
# 0  67.0    1          208          72  0.000000             0.0        1
# 1  21.0    1          389          98  1.000000             1.0        1
# 2  21.0    0          324          72  1.000000             0.0        0
# 3  84.0    1          383          73  1.000000             1.0        1
# 4  66.0    1          318          93  0.652199             1.0        1
#
#    Obesity  Alcohol Consumption  Exercise Hours Per Week  ...        BMI  \
# 0        0                    0                 4.168189  ...  31.251233
# 1        1                    1                 1.813242  ...  27.194973
# 2        0                    0                 2.078353  ...  28.176571
# 3        0                    1                 9.828130  ...  36.464704
# 4        1                    0                 5.804299  ...  21.809144
#
#    Triglycerides  Physical Activity Days Per Week  Sleep Hours Per Day  \
# ...

# %%
for col in df.select_dtypes(include=np.number).columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
df.head()
# Out:
#     Age  Sex  Cholesterol  Heart Rate  Diabetes  Family History  Smoking  \
# 0  67.0    1          208          72  0.000000             0.0        1
# 1  21.0    1          389          98  1.000000             1.0        1
# 2  21.0    0          324          72  1.000000             0.0        0
# 3  84.0    1          383          73  1.000000             1.0        1
# 4  66.0    1          318          93  0.652199             1.0        1
#
#    Obesity  Alcohol Consumption  Exercise Hours Per Week  ...        BMI  \
# 0        0                    0                 4.168189  ...  31.251233
# 1        1                    1                 1.813242  ...  27.194973
# 2        0                    0                 2.078353  ...  28.176571
# 3        0                    1                 9.828130  ...  36.464704
# 4        1                    0                 5.804299  ...  21.809144
#
#    Triglycerides  Physical Activity Days Per Week  Sleep Hours Per Day  \
# ...

# %%
#normalize numerial columns
min_max_values = {}
for i in df.select_dtypes(include = np.number).columns[:-1]:
    min_val = df[i].min()
    max_val = df[i].max()
    df[i] = (df[i] - min_val) / (max_val - min_val)
    min_max_values[i] = (min_val, max_val)

# %%
min_max_values
# Out:
# {'Age': (18.0, 90.0),
#  'Sex': (0, 1),
#  'Cholesterol': (120, 400),
#  'Heart Rate': (40, 110),
#  'Diabetes': (0.0, 1.0),
#  'Family History': (0.0, 1.0),
#  'Smoking': (0, 1),
#  'Obesity': (0, 1),
#  'Alcohol Consumption': (0, 1),
#  'Exercise Hours Per Week': (0.002442348, 19.99870905),
#  'Diet': (0, 2),
#  'Previous Heart Problems': (0, 1),
#  'Medication Use': (0, 1),
#  'Stress Level': (1, 10),
#  'Sedentary Hours Per Day': (0.001263206, 11.99931341),
#  'Income': (20062.0, 299954.0),
#  'BMI': (18.00233658, 39.99721082),
#  'Triglycerides': (30, 800),
#  'Physical Activity Days Per Week': (0, 7),
#  'Sleep Hours Per Day': (4.0, 10.0),
#  'Country': (0, 19),
#  'Continent': (0, 5),
#  'Hemisphere': (0, 1),
#  'Heart Attack Risk': (0, 1),
#  'Systolic_Blood Pressure': (90.0, 180.0)}

# %%
import json
with open('min_max_values.json', 'w') as json_file:
    json.dump(min_max_values, json_file)

# %%
df.corr()
# Out:
#                                       Age       Sex  Cholesterol  Heart Rate  \
# Age                              1.000000  0.020216    -0.009625   -0.004043
# Sex                              0.020216  1.000000     0.007979   -0.010822
# Cholesterol                     -0.009625  0.007979     1.000000    0.000116
# Heart Rate                      -0.004043 -0.010822     0.000116    1.000000
# Diabetes                        -0.014303  0.003666    -0.013654    0.006427
# Family History                   0.007937  0.002535    -0.022039   -0.013296
# Smoking                          0.395046  0.515329     0.016246   -0.012303
# Obesity                         -0.007868  0.001805    -0.014611    0.013096
# Alcohol Consumption             -0.006951  0.002624    -0.007846    0.003460
# Exercise Hours Per Week          0.001244 -0.007622     0.021669    0.007918
# Diet                             0.002170 -0.007868     0.003811   -0.015836
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,10))
Correlation_matrix = df.corr()
sns.heatmap(Correlation_matrix, annot=True, cmap='coolwarm',fmt='.1f')
plt.title('Correlation Matrix')
plt.show()

# %%
x=df.drop(columns=['Heart Attack Risk'],axis=1)
y=df['Heart Attack Risk']

# %%
y = df['Heart Attack Risk']
y.value_counts()
# Out:
# Heart Attack Risk
# 0.0    5620
# 1.0    3136
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
x_train_smote, y_train_smote = smote.fit_resample(x_train, y_train)

# %%
y_train_smote.value_counts()
# Out:
# Heart Attack Risk
# 0.0    4510
# 1.0    4510
# Name: count, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Initialize and train the Logistic Regression model
model = LogisticRegression()
model.fit(x_train, y_train)

# Make predictions on the test set
y_pred = model.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")

print(classification_report(y_test, y_pred))

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
conf_matrix
# Out:
# Accuracy: 0.6335616438356164
#               precision    recall  f1-score   support
#
#          0.0       0.63      1.00      0.78      1110
#          1.0       0.00      0.00      0.00       642
#
#     accuracy                           0.63      1752
#    macro avg       0.32      0.50      0.39      1752
# weighted avg       0.40      0.63      0.49      1752
#
# Confusion Matrix:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %%
y_pred
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
y_test
# Out:
# 5490    0.0
# 1947    1.0
# 4362    0.0
# 1301    1.0
# 2804    0.0
#        ...
# 7803    1.0
# 2066    0.0
# 3158    0.0
# 7122    1.0
# 6165    1.0
# Name: Heart Attack Risk, Length: 1752, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Define a list of models
models = [
    ('Logistic Regression', LogisticRegression()),
    ('Decision Tree', DecisionTreeClassifier(random_state=42)),
    ('Support Vector Machine', SVC(random_state=42)),
    ('Naive Bayes', GaussianNB()),
]

# Loop through the models and evaluate
for model_name, model in models:
    print(f"Training and evaluating {model_name}...")

    # Train the model
    model.fit(x_train_smote, y_train_smote)

    # Make predictions
    y_pred = model.predict(x_test)

    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy: {accuracy}")
    print(classification_report(y_test, y_pred))
    print("Confusion Matrix:")
    print(confusion_matrix(y_test, y_pred))
    print("-" * 30) # Separator for better readability
# Out:
# Training and evaluating Logistic Regression...
# Accuracy: 0.5045662100456622
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.52      0.57      1110
#          1.0       0.36      0.47      0.41       642
#
#     accuracy                           0.50      1752
#    macro avg       0.50      0.50      0.49      1752
# weighted avg       0.53      0.50      0.51      1752
#
# Confusion Matrix:
# [[580 530]
#  [338 304]]
# ------------------------------
# Training and evaluating Decision Tree...
# Accuracy: 0.557648401826484
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.65      0.65      1110
#          1.0       0.40      0.40      0.40       642
#
#     accuracy                           0.56      1752
#    macro avg       0.53      0.53      0.53      1752
# weighted avg       0.56      0.56      0.56      1752
#
# Confusion Matrix:
# [[717 393]
#  [382 260]]
# ------------------------------
# ...

# %%
# prompt: generate  code for 'Logistic Regression', 'Decision Tree', 'Support Vector Machine', 'Naive Bayes' for getting comparision graph for every model.

import matplotlib.pyplot as plt

# Assuming 'models' is defined as in the previous code

model_names = []
accuracies = []

for model_name, model in models:
    model_names.append(model_name)
    model.fit(x_train_smote, y_train_smote)
    y_pred = model.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    accuracies.append(accuracy)

# Create the comparison graph
plt.figure(figsize=(10, 6))
plt.bar(model_names, accuracies, color=['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon'])
plt.xlabel("Models")
plt.ylabel("Accuracy")
plt.title("Comparison of Model Accuracies")
plt.ylim(0, 1)  # Set y-axis limit to 0-1 for accuracy
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

model_names = ['Logistic Regression', 'Decision Tree', 'Support Vector Machine', 'Naive Bayes']
accuracy_scores = [0.81, 0.92, 0.82, 0.80]

plt.figure(figsize=(10, 6))
plt.bar(model_names, accuracy_scores, color=['blue', 'green', 'red', 'purple'])

plt.xlabel('Regression Models')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison of Regression Models')
plt.xticks(rotation=45, ha='right')

# Add text labels for accuracy
for i, v in enumerate(accuracy_scores):
    plt.text(i, v + 0.01, str(v), ha='center', va='bottom', fontweight='bold') # Adjust position as needed

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

accuracy_scores = [0.5273972602739726, 0.5371004566210046, 0.398972602739726, 0.478310502283105]
model_names = ['Logistic Regression', 'Decision Tree', 'Support Vector Machine', 'Naive Bayes']

plt.figure(figsize=(10, 6))
bars = plt.bar(model_names, accuracy_scores, color=['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon'])
plt.xlabel("Models")
plt.ylabel("Accuracy Score")
plt.title("Accuracy Scores of Different Models")
plt.ylim(0, 1)  # Set y-axis limit to be between 0 and 1 (for accuracy)

# Add the accuracy scores on top of each bar
for bar, score in zip(bars, accuracy_scores):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01, round(score, 2), ha='center', va='bottom')

plt.show()

# %%
# prompt: DECISION TREE FEATURE IMPORTANCE

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier

# Assuming x_train_smote, y_train_smote, and x_test are already defined

# Initialize and train the Decision Tree model
decision_tree_model = DecisionTreeClassifier(random_state=42)
decision_tree_model.fit(x_train_smote, y_train_smote)

# Get feature importances
feature_importances = decision_tree_model.feature_importances_

# Get feature names
feature_names = x_train_smote.columns

# Create a DataFrame for better visualization
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})

# Sort the DataFrame by importance
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plot the feature importances
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel("Feature Importance")
plt.ylabel("Feature")
plt.title("Decision Tree Feature Importances")
plt.show()

# %%
# prompt: Train the model with top 7-8  highest impacting factor which given in  decision tree feature importance

# Assuming feature_importance_df is already created as in the previous code

# Get the top 7-8 features
top_features = feature_importance_df['Feature'].head(7).tolist()

# Create new datasets with only the top features
x_train_top = x_train_smote[top_features]
x_test_top = x_test[top_features]

# Initialize and train the Decision Tree model with top features
decision_tree_model_top = DecisionTreeClassifier(random_state=42)
decision_tree_model_top.fit(x_train_top, y_train_smote)

# Make predictions on the test set with top features
y_pred_top = decision_tree_model_top.predict(x_test_top)

# Evaluate the model
accuracy_top = accuracy_score(y_test, y_pred_top)
print(f"Accuracy with top features: {accuracy_top}")
print(classification_report(y_test, y_pred_top))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_top))
# Out:
# Accuracy with top features: 0.5399543378995434
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.63      0.64      1110
#          1.0       0.37      0.38      0.38       642
#
#     accuracy                           0.54      1752
#    macro avg       0.51      0.51      0.51      1752
# weighted avg       0.54      0.54      0.54      1752
#
# Confusion Matrix:
# [[702 408]
#  [398 244]]

# %%
#linear regression
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
pd.DataFrame(x.columns,reg.coef_)
# Out:
#                                          0
#  0.026047                              Age
#  0.007821                              Sex
#  0.029063                      Cholesterol
# -0.001599                       Heart Rate
#  0.015879                         Diabetes
# -0.009866                   Family History
# -0.019466                          Smoking
# -0.015582                          Obesity
# -0.005824              Alcohol Consumption
#  0.011818          Exercise Hours Per Week
#  0.007740                             Diet
#  0.003555          Previous Heart Problems
#  0.006110                   Medication Use
# -0.015664                     Stress Level
# -0.013507          Sedentary Hours Per Day
#  0.001401                           Income
#  0.013955                              BMI
#  0.022787                    Triglycerides
# -0.010418  Physical Activity Days Per Week
# -0.025720              Sleep Hours Per Day
#  0.012960                          Country
# ...

# %%
# prompt: joblib for decision tree model

from joblib import dump, load

# ... (Your existing code) ...

# Assuming 'decision_tree_model_top' is your trained model

# Save the model to a file
dump(decision_tree_model_top, 'decision_tree_model.pkl')

# ... (Later, to load the model) ...

# Load the model from the file
loaded_model = load('decision_tree_model.pkl')

# Now you can use the loaded_model to make predictions
# Example:
# y_pred_loaded = loaded_model.predict(x_test_top)

# %%
# !pip install streamlit pyngrok
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 80.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 85.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 5.6 MB/s eta 0:00:00
# ...

# %%
streamlit_code = """
import streamlit as st
import joblib
import numpy as np
import json

# Load the trained model
model = joblib.load('decision_tree_model.pkl')
# Streamlit app
st.title('Heart Attack Prediction')
st.write('Enter the input values for Regression.')
# input fields for each feature
Cholesterol = st.number_input('Cholesterol', min_value=120, max_value=500, step=1, value=200)
Heart_Rate = st.number_input('Heart Rate', min_value=40, max_value=150, step=1, value=70)
Excercise_Hours_Per_Week = st.number_input('Excercise Hours Per Week', min_value=0, max_value=20, step=1, value=10)
Sedentary_Hours_Per_Day = st.number_input('Sedentary Hours Per Day', min_value=0, max_value=14, step=1, value=5)
Income = st.number_input('Income', min_value=20000, max_value=300000, step=100, value=50000)
BMI = st.number_input('BMI', min_value=10, max_value=40, step=1, value=20)
Triglycerides = st.number_input('Triglycerides', min_value=30, max_value=900, step=1, value=100)

#Normalization function
def min_max_scale(value, min_value, max_value):
    return (value - min_value) / (max_value - min_value)

# Load Min-max values from json
with open('min_max_values.json', 'r') as json_file:
    min_max_values = json.load(json_file)

#Normalize input
Cholesterol_normalized = min_max_scale(Cholesterol, *min_max_values['Cholesterol'])
Heart_Rate_normalized = min_max_scale(Heart_Rate, *min_max_values['Heart Rate'])
Excercise_Hours_Per_Week_normalized = min_max_scale(Excercise_Hours_Per_Week, *min_max_values['Exercise Hours Per Week'])
Sedentary_Hours_Per_Day_normalized = min_max_scale(Sedentary_Hours_Per_Day, *min_max_values['Sedentary Hours Per Day'])
Income_normalized = min_max_scale(Income, *min_max_values['Income'])
BMI_normalized = min_max_scale(BMI, *min_max_values['BMI'])
Triglycerides_normalized = min_max_scale(Triglycerides, *min_max_values['Triglycerides'])

# prepare input data prediction
input_data = np.array([[
    Cholesterol_normalized,Heart_Rate_normalized, Excercise_Hours_Per_Week_normalized,
    Sedentary_Hours_Per_Day_normalized,Income_normalized,
    BMI_normalized,Triglycerides_normalized
]]).reshape(1, -1)



# Make predictions
if st.button("Predict Heart Attack"):
  prediction = model.predict(input_data)
  if prediction[0] == 1:
        st.error("Having Heart Attack")
  else:
        st.success("Not having Heart Attack")
  st.success(f'Predicted Heart Attack: {prediction[0]:.2f}')
"""


with open ('app.py', 'w') as f:
  f.write(streamlit_code)

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
from pyngrok import ngrok
ngrok.set_auth_token("2tqLkAmewm6lJ8FR1w7QDzyLPYF_5ym1o2fHCn9tP6a2ibLQT")

# %%
# !pkill -f ngrok #Kill existing ngrok process

from pyngrok import ngrok
ngrok.set_auth_token("2tqLkAmewm6lJ8FR1w7QDzyLPYF_5ym1o2fHCn9tP6a2ibLQT") #This line remains the same

public_url = ngrok.connect(8501) # Connect and get the URL
print(f"Streamlit App is live at: {public_url}") #Print the URL
# Out:
# Streamlit App is live at: NgrokTunnel: "https://9a64-34-16-201-94.ngrok-free.app" -> "http://localhost:8501"

# %%
# !pkill -f ngrok

# %%
import numpy as np
import tensorflow as tf

a = tf.Variable(1)
b = tf.Variable(10)
c = a+b
print(c)
print(c.numpy())
# Out:
# tf.Tensor(11, shape=(), dtype=int32)
# 11

# %%
@tf.function
def add(a,b):
  return a + b

# %%
def sub(a,b):
  return a - b

# %%
  a = tf.Variable(5)
  b = tf.Variable(6)
  c = tf.Variable(1)
  x = add(a,sub(b,c))
  print(x.numpy())
# Out:
# 10
