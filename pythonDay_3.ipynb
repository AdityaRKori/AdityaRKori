# %%
import numpy as np
import pandas as pd

n1 = np.array([{1,2},{3,4}])

df = pd.DataFrame(n1, columns=['First Column','Second Column'])

# %%
# Syntax
# df = pd.read_csv(file)
# df = pd.read_excel(file,sheet_name='sheet_name')

#dataframe_nfhs = pd.read_csv('/content/Dist_Nfhs5_Sample.xlsx')
dataframe_nfhs = pd.read_excel('/content/Dist_Nfhs5_Sample.xlsx')

# %%
dataframe_nfhs.shape
# Out:
# (30, 24)

# %%
# Shape of dataframe

# Syntax
# df.shape

print('Shape of dataframe is :',dataframe_nfhs.shape)
print('Number of rows :',dataframe_nfhs.shape[0])
print('Number of columns :',dataframe_nfhs.shape[1])
# Out:
# Shape of dataframe is : (30, 24)
# Number of rows : 30
# Number of columns : 24

# %%
dataframe_nfhs.head()
# Out:
#           District   Division  All women age 15-49 years who are anaemic  \
# 0         Bagalkot    Belgavi                                       48.0
# 1        Bangalore  Bangalore                                       35.5
# 2  Bangalore Rural  Bangalore                                       44.2
# 3          Belgaum    Belgavi                                       52.9
# 4          Bellary   Kalburgi                                       58.1
#
#    Women who are overweight or obese (BMI ≥25.0 kg/m2)  \
# 0                                               28.6
# 1                                               40.1
# 2                                               33.2
# 3                                               23.8
# 4                                               27.3
#
#    Women whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2)  \
# 0                                               17.1
# 1                                               10.0
# 2                                               14.1
# 3                                               22.2
# 4                                               22.2
#
#    Blood sugar level  high (141-160 mg/dl)  \
# 0                                     11.4
# 1                                     18.8
# 2                                     11.5
# 3                                      9.9
# 4                                      9.5
#
#    Blood sugar level  high or very high (>140 mg/dl) or taking medicine to control blood sugar level  \
# 0                                               24.6
# 1                                               40.7
# 2                                               31.3
# 3                                               25.1
# 4                                               20.8
#
#    Children age 6-59 months who are anaemic (<11.0 g/dl)  \
# 0                                               63.8
# 1                                               58.9
# 2                                               60.8
# 3                                               72.7
# 4                                               67.5
#
#    Children under 5 years who are overweight  \
# 0                                        2.4
# 1                                        4.3
# 2                                        6.0
# 3                                        2.9
# 4                                        1.3
#
#    Children under 5 years who are severely wasted  ...  \
# 0                                             4.4  ...
# 1                                            11.4  ...
# 2                                             9.4  ...
# 3                                            10.2  ...
# 4                                            13.6  ...
#
#    Mothers who consumed iron folic acid for 180 days or more when they were pregnant   \
# 0                                               21.2
# 1                                               46.3
# 2                                               39.8
# 3                                               16.9
# 4                                               15.0
#
#    Average out of pocket expenditure per delivery in a public health facility (Rs.)  \
# 0                                               4576
# 1                                               3633
# 2                                               4836
# 3                                               3902
# 4                                              12348
#
#    Mothers who had at least 4 antenatal care visits   \
# 0                                               76.2
# 1                                               74.6
# 2                                               90.9
# 3                                               63.7
# 4                                               56.4
#
#    Households using clean fuel for cooking  Households using iodized salt   \
# 0                                     56.6                            81.3
# 1                                     97.2                            99.4
# 2                                     93.6                            95.6
# 3                                     74.8                            95.2
# 4                                     76.2                            84.7
#
#    Population living in households that use an improved sanitation facility  \
# 0                                               51.3
# 1                                               90.4
# 2                                               88.8
# 3                                               67.7
# 4                                               64.1
#
#    Population living in households with an improved drinkingwater source  \
# 0                                               99.2
# 1                                               99.2
# 2                                               97.9
# 3                                               94.4
# 4                                               94.7
#
#    Population living in households with electricity   Women who are literate  \
# 0                                               98.9                    69.7
# 1                                               98.8                    87.3
# 2                                               99.2                    83.8
# 3                                               99.1                    74.0
# 4                                               98.9                    64.4
#
#    Women with 10 or more years of schooling
# 0                                       37.7
# 1                                       70.1
# 2                                       56.3
# 3                                       47.8
# 4                                       39.9
#
# [5 rows x 24 columns]

# %%
dataframe_nfhs.tail()
# Out:
#           District   Division  All women age 15-49 years who are anaemic  \
# 25         Shimoga  Bangalore                                       41.9
# 26          Tumkur  Bangalore                                       49.3
# 27           Udupi     Mysore                                       47.3
# 28  Uttara Kannada    Belgavi                                       44.6
# 29          Yadgir   Kalburgi                                       57.3
#
#     Women who are overweight or obese (BMI ≥25.0 kg/m2)  \
# 25                                               30.3
# 26                                               30.4
# 27                                               22.9
# 28                                               22.6
# 29                                               18.8
#
#     Women whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2)  \
# 25                                               15.0
# 26                                               15.2
# 27                                               23.8
# 28                                               18.4
# 29                                               26.0
#
#     Blood sugar level  high (141-160 mg/dl)  \
# 25                                     14.8
# 26                                     13.0
# 27                                     12.0
# 28                                     11.1
# 29                                     10.1
#
#     Blood sugar level  high or very high (>140 mg/dl) or taking medicine to control blood sugar level  \
# 25                                               32.0
# 26                                               35.3
# 27                                               34.4
# 28                                               26.5
# 29                                               20.8
#
#     Children age 6-59 months who are anaemic (<11.0 g/dl)  \
# 25                                               68.9
# 26                                               67.6
# 27                                               58.3
# 28                                               69.0
# 29                                               76.0
#
#     Children under 5 years who are overweight  \
# 25                                        6.0
# 26                                        6.1
# 27                                        3.2
# 28                                        3.3
# 29                                        2.3
#
#     Children under 5 years who are severely wasted  ...  \
# 25                                            13.5  ...
# 26                                             3.1  ...
# 27                                             6.0  ...
# 28                                            13.1  ...
# 29                                             7.2  ...
#
#     Mothers who consumed iron folic acid for 180 days or more when they were pregnant   \
# 25                                               39.1
# 26                                               27.9
# 27                                               34.2
# 28                                               18.4
# 29                                               10.8
#
#     Average out of pocket expenditure per delivery in a public health facility (Rs.)  \
# 25                                               5284
# 26                                               4533
# 27                                               2886
# 28                                               5362
# 29                                               4386
#
#     Mothers who had at least 4 antenatal care visits   \
# 25                                               79.4
# 26                                               80.4
# 27                                               59.4
# 28                                               57.9
# 29                                               63.6
#
#     Households using clean fuel for cooking  Households using iodized salt   \
# 25                                     85.7                            91.0
# 26                                     85.3                            94.7
# 27                                     67.8                            95.6
# 28                                     73.4                            94.3
# 29                                     48.8                            76.3
#
#     Population living in households that use an improved sanitation facility  \
# 25                                               85.4
# 26                                               86.1
# 27                                               94.5
# 28                                               89.6
# 29                                               37.4
#
#     Population living in households with an improved drinkingwater source  \
# 25                                               94.6
# 26                                               96.2
# 27                                               81.5
# 28                                               84.8
# 29                                               95.2
#
#     Population living in households with electricity   Women who are literate  \
# 25                                               99.5                    79.8
# 26                                               99.6                    81.9
# 27                                               99.6                    90.3
# 28                                               99.1                    84.3
# 29                                               99.0                    48.1
#
#     Women with 10 or more years of schooling
# 25                                       49.1
# 26                                       58.9
# 27                                       55.4
# 28                                       49.2
# 29                                       26.4
#
# [5 rows x 24 columns]

# %%
print(dataframe_nfhs.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 24 columns):
#  #   Column                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                             --------------  -----
#  0   District                                                                                           30 non-null     object
#  1   Division                                                                                           30 non-null     object
#  2   All women age 15-49 years who are anaemic                                                          30 non-null     float64
#  3   Women who are overweight or obese (BMI ≥25.0 kg/m2)                                                30 non-null     float64
#  4   Women whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2)                                30 non-null     float64
#  5   Blood sugar level  high (141-160 mg/dl)                                                            30 non-null     float64
#  6   Blood sugar level  high or very high (>140 mg/dl) or taking medicine to control blood sugar level  30 non-null     float64
#  7   Children age 6-59 months who are anaemic (<11.0 g/dl)                                              30 non-null     float64
#  8   Children under 5 years who are overweight                                                          30 non-null     float64
#  9   Children under 5 years who are severely wasted                                                     30 non-null     float64
#  10  Children under 5 years who are stunted                                                             30 non-null     float64
#  11  Children under 5 years who are underweight                                                         30 non-null     float64
#  12  Households with any usual member covered under a health insurance/financing scheme                 30 non-null     float64
#  13  Mildly elevated blood pressure (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg)         30 non-null     float64
#  14  Mothers who consumed iron folic acid for 180 days or more when they were pregnant                  30 non-null     float64
#  15  Average out of pocket expenditure per delivery in a public health facility (Rs.)                   30 non-null     int64
#  16  Mothers who had at least 4 antenatal care visits                                                   30 non-null     float64
#  17  Households using clean fuel for cooking                                                            30 non-null     float64
#  18  Households using iodized salt                                                                      30 non-null     float64
#  19  Population living in households that use an improved sanitation facility                           30 non-null     float64
#  20  Population living in households with an improved drinkingwater source                              30 non-null     float64
#  21  Population living in households with electricity                                                   30 non-null     float64
#  22  Women who are literate                                                                             30 non-null     float64
#  23  Women with 10 or more years of schooling                                                           30 non-null     float64
# dtypes: float64(21), int64(1), object(2)
# memory usage: 5.8+ KB
# None

# %%
print(dataframe_nfhs.columns)
# Out:
# Index(['District', 'Division', 'All women age 15-49 years who are anaemic',
#        'Women who are overweight or obese (BMI ≥25.0 kg/m2)',
#        'Women whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2)',
#        'Blood sugar level  high (141-160 mg/dl)',
#        'Blood sugar level  high or very high (>140 mg/dl) or taking medicine to control blood sugar level',
#        'Children age 6-59 months who are anaemic (<11.0 g/dl)',
#        'Children under 5 years who are overweight',
#        'Children under 5 years who are severely wasted',
#        'Children under 5 years who are stunted',
#        'Children under 5 years who are underweight',
#        'Households with any usual member covered under a health insurance/financing scheme ',
#        'Mildly elevated blood pressure (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) ',
#        'Mothers who consumed iron folic acid for 180 days or more when they were pregnant ',
#        'Average out of pocket expenditure per delivery in a public health facility (Rs.)',
#        'Mothers who had at least 4 antenatal care visits ',
#        'Households using clean fuel for cooking',
#        'Households using iodized salt ',
#        'Population living in households that use an improved sanitation facility',
#        'Population living in households with an improved drinkingwater source',
#        'Population living in households with electricity ',
#        'Women who are literate', 'Women with 10 or more years of schooling '],
#       dtype='object')

# %%
print(dataframe_nfhs.columns(3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-29e556c1eee9> in <cell line: 1>()
# ----> 1 print(dataframe_nfhs.columns(3))
#
# TypeError: 'Index' object is not callable

# %%
dataframe_nfhs.columns[1]
# Out:
# 'Division'

# %%
series_dis = dataframe_nfhs['District']

# %%
dataframe_nfhs.loc[:, ['District', 'Division', 'All women age 15-49 years who are anaemic']]
# Out:
#             District   Division  All women age 15-49 years who are anaemic
# 0           Bagalkot    Belgavi                                       48.0
# 1          Bangalore  Bangalore                                       35.5
# 2    Bangalore Rural  Bangalore                                       44.2
# 3            Belgaum    Belgavi                                       52.9
# 4            Bellary   Kalburgi                                       58.1
# 5              Bidar   Kalburgi                                       55.9
# 6            Bijapur    Belgavi                                       52.9
# 7     Chamarajanagar     Mysore                                       46.3
# 8    Chikkaballapura  Bangalore                                       45.5
# 9        Chikmagalur     Mysore                                       40.8
# 10       Chitradurga  Bangalore                                       44.6
# 11  Dakshina Kannada     Mysore                                       38.8
# 12        Davanagere  Bangalore                                       51.7
# 13           Dharwad    Belgavi                                       52.1
# 14             Gadag    Belgavi                                       50.5
# 15          Gulbarga   Kalburgi                                       56.0
# 16            Hassan     Mysore                                       42.2
# 17            Haveri    Belgavi                                       50.8
# 18            Kodagu     Mysore                                       39.9
# 19             Kolar  Bangalore                                       43.6
# 20            Koppal   Kalburgi                                       54.8
# 21            Mandya  Bangalore                                       47.0
# 22            Mysore     Mysore                                       48.0
# 23           Raichur   Kalburgi                                       60.4
# 24        Ramanagara     Mysore                                       45.5
# 25           Shimoga  Bangalore                                       41.9
# 26            Tumkur  Bangalore                                       49.3
# 27             Udupi     Mysore                                       47.3
# 28    Uttara Kannada    Belgavi                                       44.6
# 29            Yadgir   Kalburgi                                       57.3

# %%
dataframe_nfhs.iloc[:,1]
# Out:
# 0       Belgavi
# 1     Bangalore
# 2     Bangalore
# 3       Belgavi
# 4      Kalburgi
# 5      Kalburgi
# 6       Belgavi
# 7        Mysore
# 8     Bangalore
# 9        Mysore
# 10    Bangalore
# 11       Mysore
# 12    Bangalore
# 13      Belgavi
# 14      Belgavi
# 15     Kalburgi
# 16       Mysore
# 17      Belgavi
# 18       Mysore
# 19    Bangalore
# 20     Kalburgi
# 21    Bangalore
# 22       Mysore
# 23     Kalburgi
# 24       Mysore
# 25    Bangalore
# 26    Bangalore
# 27       Mysore
# 28      Belgavi
# 29     Kalburgi
# Name: Division, dtype: object

# %%
dataframe_nfhs.iloc[:,3]
# Out:
# 0     28.6
# 1     40.1
# 2     33.2
# 3     23.8
# 4     27.3
# 5     20.8
# 6     27.4
# 7     30.6
# 8     26.6
# 9     33.2
# 10    37.4
# 11    22.2
# 12    38.1
# 13    33.8
# 14    30.6
# 15    21.8
# 16    36.1
# 17    29.1
# 18    34.7
# 19    27.9
# 20    21.9
# 21    38.7
# 22    36.4
# 23    19.9
# 24    36.5
# 25    30.3
# 26    30.4
# 27    22.9
# 28    22.6
# 29    18.8
# Name: Women who are overweight or obese (BMI ≥25.0 kg/m2), dtype: float64

# %%
dataframe_nfhs.iloc[6,7:19]
# Out:
# Children age 6-59 months who are anaemic (<11.0 g/dl)                                          65.2
# Children under 5 years who are overweight                                                       2.7
# Children under 5 years who are severely wasted                                                  4.3
# Children under 5 years who are stunted                                                         45.9
# Children under 5 years who are underweight                                                     39.0
# Households with any usual member covered under a health insurance/financing scheme             21.2
# Mildly elevated blood pressure (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg)     24.4
# Mothers who consumed iron folic acid for 180 days or more when they were pregnant              15.4
# Average out of pocket expenditure per delivery in a public health facility (Rs.)               3198
# Mothers who had at least 4 antenatal care visits                                               56.4
# Households using clean fuel for cooking                                                        60.6
# Households using iodized salt                                                                  92.3
# Name: 6, dtype: object

# %%
dataframe_nfhs.loc[(0,3), ('District', 'All women age 15-49 years who are anaemic')]
# Out:
#    District  All women age 15-49 years who are anaemic
# 0  Bagalkot                                       48.0
# 3   Belgaum                                       52.9
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['All women age 15-49 years who are anaemic'].plot(kind='hist', bins=20, title='All women age 15-49 years who are anaemic')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('District').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['All women age 15-49 years who are anaemic']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'All women age 15-49 years who are anaemic'}, axis=1)
#               .sort_values('All women age 15-49 years who are anaemic', ascending=True))
#   xs = counted['All women age 15-49 years who are anaemic']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_2.sort_values('All women age 15-49 years who are anaemic', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('District')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='District', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('All women age 15-49 years who are anaemic')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3['All women age 15-49 years who are anaemic'].plot(kind='line', figsize=(8, 4), title='All women age 15-49 years who are anaemic')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_4['District'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_4, x='All women age 15-49 years who are anaemic', y='District', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
dist_unique = dataframe_nfhs['District'].unique()
print(dist_unique)
# Out:
# ['Bagalkot' 'Bangalore' 'Bangalore Rural' 'Belgaum' 'Bellary' 'Bidar'
#  'Bijapur' 'Chamarajanagar' 'Chikkaballapura' 'Chikmagalur' 'Chitradurga'
#  'Dakshina Kannada' 'Davanagere' 'Dharwad' 'Gadag' 'Gulbarga' 'Hassan'
#  'Haveri' 'Kodagu' 'Kolar' 'Koppal' 'Mandya' 'Mysore' 'Raichur'
#  'Ramanagara' 'Shimoga' 'Tumkur' 'Udupi' 'Uttara Kannada' 'Yadgir']

# %%
df_div = dataframe_nfhs[dataframe_nfhs['Division'] == 'Bangalore']
df_div.head()
# Out:
#            District   Division  All women age 15-49 years who are anaemic  \
# 1         Bangalore  Bangalore                                       35.5
# 2   Bangalore Rural  Bangalore                                       44.2
# 8   Chikkaballapura  Bangalore                                       45.5
# 10      Chitradurga  Bangalore                                       44.6
# 12       Davanagere  Bangalore                                       51.7
#
#     Women who are overweight or obese (BMI ≥25.0 kg/m2)  \
# 1                                                40.1
# 2                                                33.2
# 8                                                26.6
# 10                                               37.4
# 12                                               38.1
#
#     Women whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2)  \
# 1                                                10.0
# 2                                                14.1
# 8                                                22.6
# 10                                               14.5
# 12                                               15.9
#
#     Blood sugar level  high (141-160 mg/dl)  \
# 1                                      18.8
# 2                                      11.5
# 8                                       9.9
# 10                                     11.7
# 12                                     12.8
#
#     Blood sugar level  high or very high (>140 mg/dl) or taking medicine to control blood sugar level  \
# 1                                                40.7
# 2                                                31.3
# 8                                                28.4
# 10                                               29.5
# 12                                               33.6
#
#     Children age 6-59 months who are anaemic (<11.0 g/dl)  \
# 1                                                58.9
# 2                                                60.8
# 8                                                59.0
# 10                                               61.1
# 12                                               70.2
#
#     Children under 5 years who are overweight  \
# 1                                         4.3
# 2                                         6.0
# 8                                         2.2
# 10                                        3.1
# 12                                        2.5
#
#     Children under 5 years who are severely wasted  ...  \
# 1                                             11.4  ...
# 2                                              9.4  ...
# 8                                              6.1  ...
# 10                                             8.3  ...
# 12                                             3.9  ...
#
#     Mothers who consumed iron folic acid for 180 days or more when they were pregnant   \
# 1                                                46.3
# 2                                                39.8
# 8                                                19.7
# 10                                               36.6
# 12                                               21.0
#
#     Average out of pocket expenditure per delivery in a public health facility (Rs.)  \
# 1                                                3633
# 2                                                4836
# 8                                                4324
# 10                                               4234
# 12                                               7508
#
#     Mothers who had at least 4 antenatal care visits   \
# 1                                                74.6
# 2                                                90.9
# 8                                                90.5
# 10                                               79.3
# 12                                               63.1
#
#     Households using clean fuel for cooking  Households using iodized salt   \
# 1                                      97.2                            99.4
# 2                                      93.6                            95.6
# 8                                      89.4                            95.0
# 10                                     80.6                            96.4
# 12                                     79.1                            94.9
#
#     Population living in households that use an improved sanitation facility  \
# 1                                                90.4
# 2                                                88.8
# 8                                                84.9
# 10                                               63.1
# 12                                               83.3
#
#     Population living in households with an improved drinkingwater source  \
# 1                                                99.2
# 2                                                97.9
# 8                                                98.1
# 10                                               97.8
# 12                                               97.5
#
#     Population living in households with electricity   Women who are literate  \
# 1                                                98.8                    87.3
# 2                                                99.2                    83.8
# 8                                                99.9                    76.3
# 10                                               99.8                    75.6
# 12                                               98.8                    76.0
#
#     Women with 10 or more years of schooling
# 1                                        70.1
# 2                                        56.3
# 8                                        48.0
# 10                                       48.3
# 12                                       47.1
#
# [5 rows x 24 columns]

# %%
df_div = dataframe_nfhs[(dataframe_nfhs['Division'] == 'Bangalore') &
          (dataframe_nfhs['All women age 15-49 years who are anaemic']> 39)]
df_div.head(1)
# Out:
#           District   Division  All women age 15-49 years who are anaemic  \
# 2  Bangalore Rural  Bangalore                                       44.2
#
#    Women who are overweight or obese (BMI ≥25.0 kg/m2)  \
# 2                                               33.2
#
#    Women whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2)  \
# 2                                               14.1
#
#    Blood sugar level  high (141-160 mg/dl)  \
# 2                                     11.5
#
#    Blood sugar level  high or very high (>140 mg/dl) or taking medicine to control blood sugar level  \
# 2                                               31.3
#
#    Children age 6-59 months who are anaemic (<11.0 g/dl)  \
# 2                                               60.8
#
#    Children under 5 years who are overweight  \
# 2                                        6.0
#
#    Children under 5 years who are severely wasted  ...  \
# 2                                             9.4  ...
#
#    Mothers who consumed iron folic acid for 180 days or more when they were pregnant   \
# 2                                               39.8
#
#    Average out of pocket expenditure per delivery in a public health facility (Rs.)  \
# 2                                               4836
#
#    Mothers who had at least 4 antenatal care visits   \
# 2                                               90.9
#
#    Households using clean fuel for cooking  Households using iodized salt   \
# 2                                     93.6                            95.6
#
#    Population living in households that use an improved sanitation facility  \
# 2                                               88.8
#
#    Population living in households with an improved drinkingwater source  \
# 2                                               97.9
#
#    Population living in households with electricity   Women who are literate  \
# 2                                               99.2                    83.8
#
#    Women with 10 or more years of schooling
# 2                                       56.3
#
# [1 rows x 24 columns]

# %%
print('Minimum is:',
      dataframe_nfhs['All women age 15-49 years who are anaemic'].min())
print('Maximum is:',
      dataframe_nfhs['All women age 15-49 years who are anaemic'].max())
print('Mean is:',
      dataframe_nfhs['All women age 15-49 years who are anaemic'].mean())
print('Standard Deviation is:',
      dataframe_nfhs['All women age 15-49 years who are anaemic'].std())
print('Median is:',
      dataframe_nfhs['All women age 15-49 years who are anaemic'].median())
# Out:
# Minimum is: 35.5
# Maximum is: 60.4
# Mean is: 48.21333333333333
# Standard Deviation is: 6.189074541331758
# Median is: 47.65

# %%
dictagg = {'All women age 15-49 years who are anaemic': 'min',
           'Women who are overweight or obese (BMI ≥25.0 kg/m2)': 'count'}
df_div_agg = dataframe_nfhs.groupby(by=['Division']).agg(dictagg)
df_div_agg.head(4)
# Out:
#            All women age 15-49 years who are anaemic  \
# Division
# Bangalore                                       35.5
# Belgavi                                         44.6
# Kalburgi                                        54.8
# Mysore                                          38.8
#
#            Women who are overweight or obese (BMI ≥25.0 kg/m2)
# Division
# Bangalore                                                  9
# Belgavi                                                    7
# Kalburgi                                                   6
# Mysore                                                     8

# %%
dataframe_nfhs_edit = dataframe_nfhs[['District',
                                      'All women age 15-49 years who are anaemic',
                                      'Children age 6-59 months who are anaemic (<11.0 g/dl)']]

df_pop = pd.read_excel('/content/Dist_Nfhs5_Sample.xlsx',
                                                             sheet_name='Population')

df_merge = pd.merge(left = dataframe_nfhs_edit,
                                                          right = df_pop,
                                                          left_on = 'District',
                                                          right_on = 'District',
                                                          how = 'left')
print(df_merge.head())
# Out:
#           District  All women age 15-49 years who are anaemic  \
# 0         Bagalkot                                       48.0
# 1        Bangalore                                       35.5
# 2  Bangalore Rural                                       44.2
# 3          Belgaum                                       52.9
# 4          Bellary                                       58.1
#
#    Children age 6-59 months who are anaemic (<11.0 g/dl)  Population
# 0                                               63.8         1889752
# 1                                               58.9         9621551
# 2                                               60.8          990923
# 3                                               72.7         4779661
# 4                                               67.5         2452595
