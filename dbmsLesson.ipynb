# %%
# prompt: read the excel file

import pandas as pd

# Replace 'your_file.xlsx' with the actual path to your Excel file
# If the file is in your Google Drive, you might need to adjust the path accordingly
# Example: /content/drive/MyDrive/your_file.xlsx
df = pd.read_excel('/content/Length_of_Stay_Dataset.xlsx')

df
# Out:
#      Patient ID  Age  Gender Admission Type Primary Diagnosis  \
# 0         74579   77  Female      Emergency            Stroke
# 1         70994   41    Male         Urgent          Fracture
# 2         58228   23   Other        Newborn      Heart Attack
# 3         44881   31  Female        Newborn      Heart Attack
# 4         84716   69   Other         Urgent          Fracture
# ..          ...  ...     ...            ...               ...
# 995       12035   35  Female       Elective          Diabetes
# 996       57742   28   Other      Emergency      Heart Attack
# 997       89928   98   Other        Newborn         Pneumonia
# 998       99495    7    Male      Emergency         Pneumonia
# 999       67395    8    Male       Elective         Pneumonia
#
#               Comorbidities  Previous Hospitalizations      BP  Heart rate  \
# 0              Hypertension                        0.0  126/76          75
# 1                       NaN                        7.0  167/99          69
# 2                   Obesity                        5.0  106/70          69
# 3    Chronic Kidney Disease                        8.0  115/99          97
# 4    Chronic Kidney Disease                        NaN  153/97          88
# ..                      ...                        ...     ...         ...
# 995                     NaN                        5.0  118/72         118
# 996                Diabetes                        4.0  179/87          85
# 997                 Obesity                        3.0  156/86          71
# 998  Chronic Kidney Disease                        8.0  122/73         102
# 999                     NaN                        9.0  110/91         116
#
#     Surgical Procedures Severity of Illness Insurance Type  \
# 0                   NaN                Mild       Medicare
# 1       Hip Replacement              Severe       Medicaid
# 2                   NaN            Critical       Medicare
# 3       Hip Replacement                Mild       Medicare
# 4       Hip Replacement              Severe       Medicaid
# ..                  ...                 ...            ...
# 995        Appendectomy                Mild       Medicaid
# 996                 NaN                Mild        Private
# 997                CABG            Critical        Private
# 998     Hip Replacement            Moderate      Uninsured
# 999     Cholecystectomy            Critical        Private
#
#     Socioeconomic Status  Hospital Total Beds    Room Type  \
# 0            Upper class                  100         Ward
# 1            Upper class                  500  Semiprivate
# 2     Below poverty line                  100  Semiprivate
# 3            Lower class                  300  Semiprivate
# 4            Upper class                  300         Ward
# ..                   ...                  ...          ...
# 995          Upper class                  100  Semiprivate
# 996         Middle class                  500      Private
# 997         Middle class                  300  Semiprivate
# 998          Lower class                  500         Ward
# 999          Upper class                  300      Private
#
#        Discharge Destination  Length of Stay in days
# 0    Rehabilitation facility                      42
# 1                   Deceased                      40
# 2                   Deceased                      41
# 3     Longterm care facility                      18
# 4     Longterm care facility                      31
# ..                       ...                     ...
# 995   Longterm care facility                      21
# 996   Longterm care facility                      28
# 997  Rehabilitation facility                      50
# 998         Home with family                      28
# 999   Longterm care facility                      60
#
# [1000 rows x 17 columns]

# %%
df.columns
# Out:
# Index(['Patient ID', 'Age', 'Gender', 'Admission Type', 'Primary Diagnosis',
#        'Comorbidities', 'Previous Hospitalizations', 'BP', 'Heart rate',
#        'Surgical Procedures', 'Severity of Illness', 'Insurance Type',
#        'Socioeconomic Status', 'Hospital Total Beds', 'Room Type',
#        'Discharge Destination', 'Length of Stay in days'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(' ', '_')
df.columns
# Out:
# Index(['Patient_ID', 'Age', 'Gender', 'Admission_Type', 'Primary_Diagnosis',
#        'Comorbidities', 'Previous_Hospitalizations', 'BP', 'Heart_rate',
#        'Surgical_Procedures', 'Severity_of_Illness', 'Insurance_Type',
#        'Socioeconomic_Status', 'Hospital_Total_Beds', 'Room_Type',
#        'Discharge_Destination', 'Length_of_Stay_in_days'],
#       dtype='object')

# %%
import psycopg2
DATABASE_URL = "postgresql://neondb_owner:Qtd1uF9jpzTR@ep-curly-truth-a5qcobin.us-east-2.aws.neon.tech/neondb?sslmode=require"

# %%
# prompt: create table = 'Patient_ID', 'Age', 'Gender', 'Admission_Type', 'Primary_Diagnosis',
#        'Comorbidities', 'Previous_Hospitalizations', 'BP', 'Heart_rate',
#        'Surgical_Procedures', 'Severity_of_Illness', 'Insurance_Type',
#        'Socioeconomic_Status', 'Hospital_Total_Beds', 'Room_Type',
#        'Discharge_Destination', 'Length_of_Stay_in_days' = remove the single quotes

conn = psycopg2.connect(DATABASE_URL)
cur = conn.cursor()

# Define the table name
table_name = 'patient_data'  # Use a more descriptive table name if needed

# Construct the CREATE TABLE statement dynamically
create_table_query = f"""
CREATE TABLE IF NOT EXISTS {table_name} (
    Patient_ID INTEGER,
    Age INTEGER,
    Gender VARCHAR(255),
    Admission_Type VARCHAR(255),
    Primary_Diagnosis VARCHAR(255),
    Comorbidities VARCHAR(255),
    Previous_Hospitalizations INTEGER,
    BP VARCHAR(255),
    Heart_rate INTEGER,
    Surgical_Procedures VARCHAR(255),
    Severity_of_Illness VARCHAR(255),
    Insurance_Type VARCHAR(255),
    Socioeconomic_Status VARCHAR(255),
    Hospital_Total_Beds INTEGER,
    Room_Type VARCHAR(255),
    Discharge_Destination VARCHAR(255),
    Length_of_Stay_in_days INTEGER
)
"""
cur.execute(create_table_query)
conn.commit()
print(f"Table '{table_name}' created successfully.")

# Insert data into the table using a parameterized query
# for index, row in df.iterrows():
#     insert_query = f"""
#     INSERT INTO {table_name} (
#         Patient_ID, Age, Gender, Admission_Type, Primary_Diagnosis, Comorbidities,
#         Previous_Hospitalizations, BP, Heart_rate, Surgical_Procedures,
#         Severity_of_Illness, Insurance_Type, Socioeconomic_Status,
#         Hospital_Total_Beds, Room_Type, Discharge_Destination, Length_of_Stay_in_days
#     ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#     """
#     cur.execute(insert_query, tuple(row))
#     conn.commit()

cur.close()
conn.close()

# %%
create_table_query = """
CREATE TABLE IF NOT EXISTS length_of_stay (
    'Patient_ID', 'Age', 'Gender', 'Admission_Type', 'Primary_Diagnosis',
       'Comorbidities', 'Previous_Hospitalizations', 'BP', 'Heart_rate',
       'Surgical_Procedures', 'Severity_of_Illness', 'Insurance_Type',
       'Socioeconomic_Status', 'Hospital_Total_Beds', 'Room_Type',
       'Discharge_Destination', 'Length_of_Stay_in_days'
       );
       """

# %%
# CREATE TABLE QUERY
create_table_query = """
CREATE TABLE IF NOT EXISTS length_of_stay1 (
  Patient_ID integer, Age integer, Gender text, Admission_Type text, Primary_Diagnosis text,
       Comorbidities text, Previous_Hospitalizations integer, BP text, Heart_rate decimal,
       Surgical_Procedures text, Severity_of_Illness text, Insurance_Type text,
       Socioeconomic_Status text, Hospital_Total_Beds integer, Room_Type text,
       Discharge_Destination text, Length_of_Stay_in_days integer
);
"""

# %%
try:

  conn = psycopg2.connect(DATABASE_URL)
  cur = conn.cursor()
  cur.execute(create_table_query)
  conn.commit()
  cur.close()
  conn.close()

except Exception as e:
    print(e)

# %%
df.shape
# Out:
# (1000, 17)

# %%
import numpy as np
df = df.replace({np.nan: None})

# %%
tuples = [tuple(x) for x in df.to_numpy()]

# %%
df
# Out:
#      Patient_ID  Age  Gender Admission_Type Primary_Diagnosis  \
# 0         74579   77  Female      Emergency            Stroke
# 1         70994   41    Male         Urgent          Fracture
# 2         58228   23   Other        Newborn      Heart Attack
# 3         44881   31  Female        Newborn      Heart Attack
# 4         84716   69   Other         Urgent          Fracture
# ..          ...  ...     ...            ...               ...
# 995       12035   35  Female       Elective          Diabetes
# 996       57742   28   Other      Emergency      Heart Attack
# 997       89928   98   Other        Newborn         Pneumonia
# 998       99495    7    Male      Emergency         Pneumonia
# 999       67395    8    Male       Elective         Pneumonia
#
#               Comorbidities Previous_Hospitalizations      BP  Heart_rate  \
# 0              Hypertension                       0.0  126/76          75
# 1                      None                       7.0  167/99          69
# 2                   Obesity                       5.0  106/70          69
# 3    Chronic Kidney Disease                       8.0  115/99          97
# 4    Chronic Kidney Disease                      None  153/97          88
# ..                      ...                       ...     ...         ...
# 995                    None                       5.0  118/72         118
# 996                Diabetes                       4.0  179/87          85
# 997                 Obesity                       3.0  156/86          71
# 998  Chronic Kidney Disease                       8.0  122/73         102
# 999                    None                       9.0  110/91         116
#
#     Surgical_Procedures Severity_of_Illness Insurance_Type  \
# 0                  None                Mild       Medicare
# 1       Hip Replacement              Severe       Medicaid
# 2                  None            Critical       Medicare
# 3       Hip Replacement                Mild       Medicare
# 4       Hip Replacement              Severe       Medicaid
# ..                  ...                 ...            ...
# 995        Appendectomy                Mild       Medicaid
# 996                None                Mild        Private
# 997                CABG            Critical        Private
# 998     Hip Replacement            Moderate      Uninsured
# 999     Cholecystectomy            Critical        Private
#
#     Socioeconomic_Status  Hospital_Total_Beds    Room_Type  \
# 0            Upper class                  100         Ward
# 1            Upper class                  500  Semiprivate
# 2     Below poverty line                  100  Semiprivate
# 3            Lower class                  300  Semiprivate
# 4            Upper class                  300         Ward
# ..                   ...                  ...          ...
# 995          Upper class                  100  Semiprivate
# 996         Middle class                  500      Private
# 997         Middle class                  300  Semiprivate
# 998          Lower class                  500         Ward
# 999          Upper class                  300      Private
#
#        Discharge_Destination  Length_of_Stay_in_days
# 0    Rehabilitation facility                      42
# 1                   Deceased                      40
# 2                   Deceased                      41
# 3     Longterm care facility                      18
# 4     Longterm care facility                      31
# ..                       ...                     ...
# 995   Longterm care facility                      21
# 996   Longterm care facility                      28
# 997  Rehabilitation facility                      50
# 998         Home with family                      28
# 999   Longterm care facility                      60
#
# [1000 rows x 17 columns]

# %%
from psycopg2.extras import execute_values
insert_query = """INSERT INTO length_of_stay1 (Patient_ID, Age, Gender, Admission_Type, Primary_Diagnosis,
       Comorbidities, Previous_Hospitalizations, BP, Heart_rate,
       Surgical_Procedures, Severity_of_Illness, Insurance_Type,
       Socioeconomic_Status, Hospital_Total_Beds, Room_Type,
       Discharge_Destination, Length_of_Stay_in_days) VALUES %s"""

try:
  conn = psycopg2.connect(DATABASE_URL)
  cursor = conn.cursor()
  execute_values(cursor, insert_query, tuples)
  conn.commit()
  cursor.close()
  conn.close()
except Exception as e:
  print(e)

# %%
query1 ="""SELECT * FROM length_of_stay1"""

# %%
try:
  conn = psycopg2.connect(DATABASE_URL)
  cur = conn.cursor()
  cur.execute(query1)
  rows = cur.fetchall()
  df = pd.DataFrame(rows, columns=df.columns)
  cur.close()
  conn.close()
except Exception as e:
  print(e)

# %%
df.head()
# Out:
#    Patient_ID  Age  Gender Admission_Type Primary_Diagnosis Comorbidities  \
# 0       74579   77  Female      Emergency            Stroke  Hypertension
# 1       70994   41    Male         Urgent          Fracture           NaN
# 2       74579   77  Female      Emergency            Stroke  Hypertension
# 3       70994   41    Male         Urgent          Fracture          None
# 4       58228   23   Other        Newborn      Heart Attack       Obesity
#
#    Previous_Hospitalizations      BP Heart_rate Surgical_Procedures  \
# 0                        0.0  126/76         75                 NaN
# 1                        7.0  167/99         69     Hip Replacement
# 2                        0.0  126/76         75                None
# 3                        7.0  167/99         69     Hip Replacement
# 4                        5.0  106/70         69                None
#
#   Severity_of_Illness Insurance_Type Socioeconomic_Status  \
# 0                Mild       Medicare          Upper class
# 1              Severe       Medicaid          Upper class
# 2                Mild       Medicare          Upper class
# 3              Severe       Medicaid          Upper class
# 4            Critical       Medicare   Below poverty line
#
#    Hospital_Total_Beds    Room_Type    Discharge_Destination  \
# 0                  100         Ward  Rehabilitation facility
# 1                  500  Semiprivate                 Deceased
# 2                  100         Ward  Rehabilitation facility
# 3                  500  Semiprivate                 Deceased
# 4                  100  Semiprivate                 Deceased
#
#    Length_of_Stay_in_days
# 0                      42
# 1                      40
# 2                      42
# 3                      40
# 4                      41

# %%
query2 = """select * from medicalrecords"""

# %%
try:
  conn = psycopg2.connect(DATABASE_URL)
  cursor = conn.cursor()
  cursor.execute(query2)
  rows = cursor.fetchall()
  df2 = pd.DataFrame(rows,columns=["name","diagnosis",'prescription','doctor_id'])
  cursor.close()
  conn.close()

except Exception as e:
  print(e)

# %%
df.head()
# Out:
#    Patient_ID  Age  Gender Admission_Type Primary_Diagnosis Comorbidities  \
# 0       74579   77  Female      Emergency            Stroke  Hypertension
# 1       70994   41    Male         Urgent          Fracture           NaN
# 2       74579   77  Female      Emergency            Stroke  Hypertension
# 3       70994   41    Male         Urgent          Fracture          None
# 4       58228   23   Other        Newborn      Heart Attack       Obesity
#
#    Previous_Hospitalizations      BP Heart_rate Surgical_Procedures  \
# 0                        0.0  126/76         75                 NaN
# 1                        7.0  167/99         69     Hip Replacement
# 2                        0.0  126/76         75                None
# 3                        7.0  167/99         69     Hip Replacement
# 4                        5.0  106/70         69                None
#
#   Severity_of_Illness Insurance_Type Socioeconomic_Status  \
# 0                Mild       Medicare          Upper class
# 1              Severe       Medicaid          Upper class
# 2                Mild       Medicare          Upper class
# 3              Severe       Medicaid          Upper class
# 4            Critical       Medicare   Below poverty line
#
#    Hospital_Total_Beds    Room_Type    Discharge_Destination  \
# 0                  100         Ward  Rehabilitation facility
# 1                  500  Semiprivate                 Deceased
# 2                  100         Ward  Rehabilitation facility
# 3                  500  Semiprivate                 Deceased
# 4                  100  Semiprivate                 Deceased
#
#    Length_of_Stay_in_days
# 0                      42
# 1                      40
# 2                      42
# 3                      40
# 4                      41

# %%
query4 = """select gender,avg(age) from length_of_stay group by gender """

# %%
query4 = """select gender,avg(age) from length_of_stay group by gender """
try:
  conn = psycopg2.connect(DATABASE_URL)
  cursor = conn.cursor()
  cursor.execute(query4)
  rows = cursor.fetchall()
  df4 = pd.DataFrame(rows,columns=['gender','age'])
  cursor.close()
  conn.close()

except Exception as e:
  print(e)
df
# Out:
#       Patient_ID  Age  Gender Admission_Type Primary_Diagnosis  \
# 0          74579   77  Female      Emergency            Stroke
# 1          70994   41    Male         Urgent          Fracture
# 2          74579   77  Female      Emergency            Stroke
# 3          70994   41    Male         Urgent          Fracture
# 4          58228   23   Other        Newborn      Heart Attack
# ...          ...  ...     ...            ...               ...
# 997        12035   35  Female       Elective          Diabetes
# 998        57742   28   Other      Emergency      Heart Attack
# 999        89928   98   Other        Newborn         Pneumonia
# 1000       99495    7    Male      Emergency         Pneumonia
# 1001       67395    8    Male       Elective         Pneumonia
#
#                Comorbidities  Previous_Hospitalizations      BP Heart_rate  \
# 0               Hypertension                        0.0  126/76         75
# 1                        NaN                        7.0  167/99         69
# 2               Hypertension                        0.0  126/76         75
# 3                       None                        7.0  167/99         69
# 4                    Obesity                        5.0  106/70         69
# ...                      ...                        ...     ...        ...
# 997                     None                        5.0  118/72        118
# 998                 Diabetes                        4.0  179/87         85
# 999                  Obesity                        3.0  156/86         71
# 1000  Chronic Kidney Disease                        8.0  122/73        102
# 1001                    None                        9.0  110/91        116
#
#      Surgical_Procedures Severity_of_Illness Insurance_Type  \
# 0                    NaN                Mild       Medicare
# 1        Hip Replacement              Severe       Medicaid
# 2                   None                Mild       Medicare
# 3        Hip Replacement              Severe       Medicaid
# 4                   None            Critical       Medicare
# ...                  ...                 ...            ...
# 997         Appendectomy                Mild       Medicaid
# 998                 None                Mild        Private
# 999                 CABG            Critical        Private
# 1000     Hip Replacement            Moderate      Uninsured
# 1001     Cholecystectomy            Critical        Private
#
#      Socioeconomic_Status  Hospital_Total_Beds    Room_Type  \
# 0             Upper class                  100         Ward
# 1             Upper class                  500  Semiprivate
# 2             Upper class                  100         Ward
# 3             Upper class                  500  Semiprivate
# 4      Below poverty line                  100  Semiprivate
# ...                   ...                  ...          ...
# 997           Upper class                  100  Semiprivate
# 998          Middle class                  500      Private
# 999          Middle class                  300  Semiprivate
# 1000          Lower class                  500         Ward
# 1001          Upper class                  300      Private
#
#         Discharge_Destination  Length_of_Stay_in_days
# 0     Rehabilitation facility                      42
# 1                    Deceased                      40
# 2     Rehabilitation facility                      42
# 3                    Deceased                      40
# 4                    Deceased                      41
# ...                       ...                     ...
# 997    Longterm care facility                      21
# 998    Longterm care facility                      28
# 999   Rehabilitation facility                      50
# 1000         Home with family                      28
# 1001   Longterm care facility                      60
#
# [1002 rows x 17 columns]

# %%
query5 = """UPDATE length_of_stay SET Gender = 'Male' WHERE Patient_ID = 59213"""

try:
  conn = psycopg2.connect(DATABASE_URL)
  cursor = conn.cursor()
  cursor.execute(query5)
  conn.commit()
  cursor.close()
  conn.close()
  print("Updated successfully")
except Exception as e:
  print(e)
# Out:
# Updated successfully
